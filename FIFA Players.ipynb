# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('dataset/fifa_player.csv')
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data = data.drop("Unnamed: 0", 1)
data.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %%
data.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Photo                0
# Nationality          0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 88, dtype: int64

# %%
data["Nationality"].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
# oldest player
data[data["Age"] == data["Age"].max()]["Name"]
# Out:
# 4741    O. Pérez
# Name: Name, dtype: object

# %%
data[data["Name"] == "Neymar Jr"]["Value"]
# Out:
# 2    €118.5M
# Name: Value, dtype: object

# %%
data[data["Club"] == "Liverpool"]["Name"]
# Out:
# 26                    M. Salah
# 58                     S. Mané
# 59                 V. van Dijk
# 61             Roberto Firmino
# 81                     Alisson
# 118                    Fabinho
# 161                   N. Keïta
# 241               A. Robertson
# 296               J. Henderson
# 302               G. Wijnaldum
# 368                  D. Lovren
# 370                 X. Shaqiri
# 409                  J. Milner
# 481      A. Oxlade-Chamberlain
# 483                   J. Matip
# 515                 A. Lallana
# 529               D. Sturridge
# 665                   N. Clyne
# 703                S. Mignolet
# 735        T. Alexander-Arnold
# 755                   J. Gomez
# 1063                  D. Origi
# 1194            Alberto Moreno
# 2405               L. Marković
# 4763                D. Solanke
# 8853          Pedro Chirivella
# 13503              R. Brewster
# 13961                 C. Jones
# 14036              N. Phillips
# 14252           Rafael Camacho
# ...

# %%
data[data["Nationality"] == "India"]["Name"]
# Out:
# 8605          S. Chhetri
# 10011         S. Jhingan
# 12598      J. Lalpekhlua
# 12811    G. Singh Sandhu
# 13508      A. Edathodika
# 14054          P. Halder
# 14199           P. Kotal
# 14218           L. Ralte
# 14705             N. Das
# 14786           U. Singh
# 14915         H. Narzary
# 15356           R. Singh
# 15643           S. Singh
# 15652           A. Thapa
# 15855         M. Rafique
# 15864           A. Singh
# 15884           B. Singh
# 16135            S. Bose
# 16265          R. Borges
# 16450            S. Paul
# 16499          A. Mondal
# 16539    L. Lalruatthara
# 16793         E. Lyngdoh
# 16903     J. Lalrinzuala
# 16976       A. Kuruniyan
# 17129           J. Singh
# 17197           V. Kaith
# 17339           S. Passi
# 17436     D. Lalhlimpuia
# 17539           C. Singh
# Name: Name, dtype: object

# %%
data[(data["Nationality"] == "England") & (data["Club"] == "Chelsea")]["Name"]
# Out:
# 534                G. Cahill
# 646               R. Barkley
# 681            D. Drinkwater
# 1085         R. Loftus-Cheek
# 3937                R. Green
# 5121          C. Hudson-Odoi
# 14646    M. Taylor-Crossdale
# 15322           G. McEachran
# 15846               M. Guehi
# Name: Name, dtype: object

# %%
data["Preferred Foot"].value_counts().plot(kind = 'bar');

# %%
data['Wage'].head()
# Out:
# 0    €565K
# 1    €405K
# 2    €290K
# 3    €260K
# 4    €355K
# Name: Wage, dtype: object

# %%
data['Value'].head()
# Out:
# 0    €110.5M
# 1       €77M
# 2    €118.5M
# 3       €72M
# 4      €102M
# Name: Value, dtype: object

# %%
from decimal import *
def text_to_num(text):
    digit = {'K': 3, 'M': 6}
    new_text = text[1:]
    if new_text[-1] in digit:
        num = new_text[:-1]
        magnitude = new_text[-1]
        return Decimal(num) * 10 ** digit[magnitude]
    else:
        return Decimal(new_text)
    
def convert_into_float(df_fifa):
    cols = ['Value', 'Wage']
    data[cols] = data[cols].applymap(text_to_num)
    return data
convert_into_float(data)

data["Value"] = data["Value"].astype(np.int64)

# %%
data = data.sort_values(by = ['Value'], ascending = False)
plt.figure(figsize = (20, 6))
sns.barplot(x = data["Value"], y = data["Name"][:20]);

# %%
data = data.sort_values(by = ['Wage'], ascending = False)
plt.figure(figsize = (20, 6))
sns.barplot(x = data["Wage"], y = data["Name"][:20]);

# %%
plt.figure(figsize = (20, 7))
plt.scatter(data["Potential"], data["Wage"]);

# %%
plt.figure(figsize = (20, 6))
data["Position"].value_counts().plot(kind = 'bar');

# %%
plt.figure(figsize = (20, 7))
plt.xticks(rotation = 90)
sns.barplot(y=data["Overall"], x=data["Position"]);

# %%
f, axes = plt.subplots(1, 2, figsize = (8, 4))
sns.boxplot(y = data["Potential"], ax = axes[0],);
sns.boxplot(y = data["Overall"], ax = axes[1],);

# %%
plt.figure(figsize = (20, 7))
plt.xticks(rotation = 90, fontweight = 'bold')
sns.stripplot(data["Nationality"][:250], data["Wage"]);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data["Jersey Number"] = data["Jersey Number"].fillna(data["Jersey Number"].mode()[0])
data["Jersey Number"] = data["Jersey Number"].astype(np.int64)
data["Jersey Number"].value_counts()
fig = plt.figure(figsize = (25, 6))
data["Jersey Number"].hist(bins=40);

# %%
plt.figure(figsize = (20, 6))
data["Jersey Number"].value_counts().plot(kind='bar');

# %%
plt.figure(figsize = (20, 8))
plt.ticklabel_format(style = 'plain')
plt.plot(data["Club"].value_counts()[:250], data["Club"][:250], "o", color = 'Red')
plt.legend(["Club"], loc ="upper right")
plt.grid()
plt.xticks(fontweight = 'bold')
plt.show()

# %%
sns.countplot(x="Nationality", data=data, order=data["Nationality"].value_counts().index[:5]);

# %%
from wordcloud import WordCloud, STOPWORDS
text = " ".join(Nationality for Nationality in data.Nationality)
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
plt.figure(figsize = (20, 5))
plt.imshow(word_cloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %%
sns.displot(x=data["Age"], bins=30);

# %%
sns.countplot(x="International Reputation", data=data);
